# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
import re
import csv
import librosa
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import optimizers,regularizers
from tensorflow.keras.models import Sequential, load_model, model_from_json 
from tensorflow.keras.layers import Conv2D,Dense,Activation,Flatten,Dropout,AveragePooling2D,BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.python.framework.ops import disable_eager_execution
from sklearn.metrics import accuracy_score
from tensorflow.python.client import device_lib

#Generate training, test set
def walk(folder):
    '''Walk through every files in a directory'''
    for dirpath, dirs, files in os.walk(folder):
        for filename in files:
            yield dirpath, filename

def iscsv(ext):
    csvlist = ['.csv']
    if ext in csvlist:
        return True
    else:
        return False

def find_word(path):
    keywords=[]
    for folder, filename in walk(path):
        keyword = re.split('/',folder)[-1]
        if keyword not in keywords:
            keywords.append(keyword)
    return tuple(keywords)
  
def count_ext(path, ext):
    count = 0
    for folder, filename in walk(path):
        if filename[-len(ext):] == ext:
            count += 1
    return count

destpath = '/content/gdrive/MyDrive/수학캡스톤_공유폴더/data/rawdata/'
save_path = '/content/gdrive/MyDrive/수학캡스톤_공유폴더/eunu/result/'
try:
    os.mkdir(save_path)
except:
    pass
import keras
X_data = np.load(destpath+'X_10.npy')
Y_data = np.load(destpath+'Y_10.npy')
print('X_data shape:',np.shape(X_data))
print('Y_data shape:',np.shape(Y_data))
keywords = ('yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop','go')
'''
def split_dataset(Y,ratio=0.2):
    test_ix = np.array([])
    for i in np.unique(Y):
        idx = np.reshape(np.where(Y==i),-1)
        idx = np.random.choice(idx,int(len(idx)*ratio),False)
        test_ix = np.concatenate((test_ix,idx),axis=None)
    test_ix = np.sort(test_ix.astype(int))
    train_ix = list(set(range(len(temp)))-set(test_ix))
    return train_ix, test_ix
train_ix, test_ix = split_dataset(Y_data,0.1)
df = pd.DataFrame(test_ix)
df.to_csv(destpath+'testidx.csv',sep=',',header=False,
          float_format='%.2f',index=False)
'''
csvpath = destpath+'testidx.csv'
test_ix = pd.read_csv(csvpath,header=None)[0]
train_ix = list(set(range(len(Y_data)))-set(test_ix))
train_X = X_data[train_ix]
train_Y = Y_data[train_ix]
test_X = X_data[test_ix]
test_Y = Y_data[test_ix]

#shuffle data before training
tot_ix = range(len(train_X))
rand_ix = np.random.choice(tot_ix,len(train_X),False)
train_X = train_X[rand_ix]
train_Y = train_Y[rand_ix]

from keras.utils.np_utils import to_categorical
train_X = np.expand_dims(train_X,-1)
test_X = np.expand_dims(test_X,-1)
num_class = len(np.unique(Y_data))
train_Y = to_categorical(train_Y,num_class)
test_Y = to_categorical(test_Y,num_class)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# X_data shape: (23682, 40, 44)
# Y_data shape: (23682,)

# %%
from tensorflow.keras.layers import Softmax, DepthwiseConv2D, LeakyReLU, GlobalAveragePooling2D
inp_shape = np.shape(train_X)[1:]

def build_model():
    model = Sequential()
    model.add(Conv2D(filters=70, kernel_size=(3,3), strides = 1, padding ='same', input_shape=inp_shape, activation = 'relu'))
    model.add(AveragePooling2D(pool_size=(3,3), strides=2))
    model.add(DepthwiseConv2D(kernel_size=(3,3),strides=(1,1),padding='same'))
    model.add(Conv2D(filters=50, kernel_size=(3,3), strides = 1, padding ='same', activation = 'relu'))
    model.add(BatchNormalization())
    model.add(DepthwiseConv2D(kernel_size=(3,3),strides=(1,1),padding='same'))
    model.add(Conv2D(filters=30, kernel_size=(3,3), strides = 1, padding ='same', activation = 'relu'))
    model.add(BatchNormalization())    
    model.add(AveragePooling2D(pool_size=(3,3), strides=None))
    model.add(Flatten())
    model.add(Dense(50, activation = 'relu',kernel_regularizer=regularizers.l2(0.001)))
    model.add(Dropout(0.1))
    model.add(Dense(10, activation = 'linear'))
    model.add(LeakyReLU())
    model.add(Softmax())
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

callbacks_list  = [
    EarlyStopping( monitor = 'loss',  min_delta=0.0001, patience=30,
                  verbose=1, mode='auto'),
    ModelCheckpoint(filepath = save_path+"/weights.{epoch:02d}-{val_loss:.4f}-{val_accuracy:.4f}.hdf5",
                    monitor = 'val_loss', save_best_only=True ),
    ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=10, verbose=1, mode='min', min_delta=1e-4)]

model = build_model()
model.summary()
history = model.fit(train_X,train_Y,epochs=200,batch_size=64,validation_data=(test_X,test_Y),callbacks=callbacks_list)
pd.DataFrame(history.history).to_csv(save_path+"/history.csv")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 40, 44, 70)        700
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 19, 21, 70)        0
# _________________________________________________________________
# depthwise_conv2d_2 (Depthwis (None, 19, 21, 70)        700
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 19, 21, 50)        31550
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 19, 21, 50)        200
# _________________________________________________________________
# depthwise_conv2d_3 (Depthwis (None, 19, 21, 50)        500
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 19, 21, 30)        13530
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 19, 21, 30)        120
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 6, 7, 30)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1260)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                63050
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                510
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 10)                0
# _________________________________________________________________
# softmax_1 (Softmax)          (None, 10)                0
# =================================================================
# Total params: 110,860
# Trainable params: 110,700
# Non-trainable params: 160
# _________________________________________________________________
# Epoch 1/200
# 334/334 [==============================] - 5s 12ms/step - loss: 1.1612 - accuracy: 0.6312 - val_loss: 1.2234 - val_accuracy: 0.6115
# Epoch 2/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4299 - accuracy: 0.8813 - val_loss: 0.3478 - val_accuracy: 0.9044
# Epoch 3/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.2962 - accuracy: 0.9238 - val_loss: 0.3035 - val_accuracy: 0.9145
# Epoch 4/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.2428 - accuracy: 0.9409 - val_loss: 0.3072 - val_accuracy: 0.9162
# Epoch 5/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.2076 - accuracy: 0.9517 - val_loss: 0.2491 - val_accuracy: 0.9327
# Epoch 6/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.1888 - accuracy: 0.9558 - val_loss: 0.3029 - val_accuracy: 0.9158
# Epoch 7/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.1641 - accuracy: 0.9631 - val_loss: 0.2398 - val_accuracy: 0.9395
# Epoch 8/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.1476 - accuracy: 0.9688 - val_loss: 0.2297 - val_accuracy: 0.9416
# Epoch 9/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.1456 - accuracy: 0.9698 - val_loss: 0.2568 - val_accuracy: 0.9344
# Epoch 10/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.1389 - accuracy: 0.9721 - val_loss: 0.2485 - val_accuracy: 0.9344
# Epoch 11/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.1609 - accuracy: 0.9651 - val_loss: 0.2233 - val_accuracy: 0.9433
# Epoch 12/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.1173 - accuracy: 0.9797 - val_loss: 0.2306 - val_accuracy: 0.9403
# Epoch 13/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.1066 - accuracy: 0.9835 - val_loss: 0.2972 - val_accuracy: 0.9242
# Epoch 14/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.1099 - accuracy: 0.9810 - val_loss: 0.2463 - val_accuracy: 0.9403
# Epoch 15/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.1103 - accuracy: 0.9808 - val_loss: 0.2269 - val_accuracy: 0.9433
# Epoch 16/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.1043 - accuracy: 0.9836 - val_loss: 0.2187 - val_accuracy: 0.9484
# Epoch 17/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.1039 - accuracy: 0.9830 - val_loss: 0.2335 - val_accuracy: 0.9484
# Epoch 18/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.1021 - accuracy: 0.9845 - val_loss: 0.2289 - val_accuracy: 0.9526
# Epoch 19/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0908 - accuracy: 0.9880 - val_loss: 0.3027 - val_accuracy: 0.9327
# Epoch 20/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.1081 - accuracy: 0.9818 - val_loss: 0.2687 - val_accuracy: 0.9374
# Epoch 21/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0891 - accuracy: 0.9891 - val_loss: 0.2663 - val_accuracy: 0.9454
# Epoch 22/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0812 - accuracy: 0.9910 - val_loss: 0.2594 - val_accuracy: 0.9505
# Epoch 23/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0827 - accuracy: 0.9895 - val_loss: 0.2680 - val_accuracy: 0.9429
# Epoch 24/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.1229 - accuracy: 0.9785 - val_loss: 0.2601 - val_accuracy: 0.9437
# Epoch 25/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0819 - accuracy: 0.9917 - val_loss: 0.2510 - val_accuracy: 0.9416
# Epoch 26/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0740 - accuracy: 0.9923 - val_loss: 0.2305 - val_accuracy: 0.9463
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
# Epoch 27/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0723 - accuracy: 0.9914 - val_loss: 0.2482 - val_accuracy: 0.9463
# Epoch 28/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0664 - accuracy: 0.9935 - val_loss: 0.2727 - val_accuracy: 0.9374
# Epoch 29/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0634 - accuracy: 0.9939 - val_loss: 0.2307 - val_accuracy: 0.9458
# Epoch 30/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0690 - accuracy: 0.9916 - val_loss: 0.2457 - val_accuracy: 0.9450
# Epoch 31/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0916 - accuracy: 0.9865 - val_loss: 0.2693 - val_accuracy: 0.9420
# Epoch 32/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.1106 - accuracy: 0.9823 - val_loss: 0.2689 - val_accuracy: 0.9441
# Epoch 33/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0713 - accuracy: 0.9944 - val_loss: 0.2184 - val_accuracy: 0.9526
# Epoch 34/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0531 - accuracy: 0.9973 - val_loss: 0.2095 - val_accuracy: 0.9543
# Epoch 35/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0503 - accuracy: 0.9965 - val_loss: 0.2129 - val_accuracy: 0.9534
# Epoch 36/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0578 - accuracy: 0.9934 - val_loss: 0.2299 - val_accuracy: 0.9467
# Epoch 37/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0691 - accuracy: 0.9916 - val_loss: 0.2472 - val_accuracy: 0.9522
# Epoch 38/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0650 - accuracy: 0.9932 - val_loss: 0.2696 - val_accuracy: 0.9450
# Epoch 39/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0719 - accuracy: 0.9905 - val_loss: 0.2648 - val_accuracy: 0.9454
# Epoch 40/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0651 - accuracy: 0.9933 - val_loss: 0.2475 - val_accuracy: 0.9518
# Epoch 41/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0616 - accuracy: 0.9943 - val_loss: 0.2764 - val_accuracy: 0.9505
# Epoch 42/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0595 - accuracy: 0.9942 - val_loss: 0.2481 - val_accuracy: 0.9501
# Epoch 43/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0590 - accuracy: 0.9932 - val_loss: 0.2443 - val_accuracy: 0.9475
# Epoch 44/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0914 - accuracy: 0.9850 - val_loss: 0.2654 - val_accuracy: 0.9437
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
# Epoch 45/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0768 - accuracy: 0.9918 - val_loss: 0.3035 - val_accuracy: 0.9395
# Epoch 46/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0517 - accuracy: 0.9979 - val_loss: 0.2290 - val_accuracy: 0.9577
# Epoch 47/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0415 - accuracy: 0.9984 - val_loss: 0.2227 - val_accuracy: 0.9556
# Epoch 48/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0367 - accuracy: 0.9986 - val_loss: 0.1862 - val_accuracy: 0.9551
# Epoch 49/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0405 - accuracy: 0.9960 - val_loss: 0.2235 - val_accuracy: 0.9526
# Epoch 50/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0653 - accuracy: 0.9913 - val_loss: 0.3146 - val_accuracy: 0.9365
# Epoch 51/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0603 - accuracy: 0.9927 - val_loss: 0.2853 - val_accuracy: 0.9479
# Epoch 52/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0496 - accuracy: 0.9971 - val_loss: 0.2346 - val_accuracy: 0.9556
# Epoch 53/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0448 - accuracy: 0.9962 - val_loss: 0.2386 - val_accuracy: 0.9547
# Epoch 54/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0563 - accuracy: 0.9932 - val_loss: 0.2464 - val_accuracy: 0.9522
# Epoch 55/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0538 - accuracy: 0.9944 - val_loss: 0.2498 - val_accuracy: 0.9513
# Epoch 56/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0607 - accuracy: 0.9930 - val_loss: 0.2425 - val_accuracy: 0.9518
# Epoch 57/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0592 - accuracy: 0.9935 - val_loss: 0.2632 - val_accuracy: 0.9484
# Epoch 58/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0541 - accuracy: 0.9948 - val_loss: 0.2473 - val_accuracy: 0.9573
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.0007290000503417104.
# Epoch 59/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0446 - accuracy: 0.9970 - val_loss: 0.2426 - val_accuracy: 0.9513
# Epoch 60/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0391 - accuracy: 0.9977 - val_loss: 0.2333 - val_accuracy: 0.9539
# Epoch 61/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0411 - accuracy: 0.9964 - val_loss: 0.2060 - val_accuracy: 0.9560
# Epoch 62/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0363 - accuracy: 0.9980 - val_loss: 0.2220 - val_accuracy: 0.9573
# Epoch 63/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0391 - accuracy: 0.9966 - val_loss: 0.2919 - val_accuracy: 0.9437
# Epoch 64/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0447 - accuracy: 0.9955 - val_loss: 0.2623 - val_accuracy: 0.9479
# Epoch 65/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0535 - accuracy: 0.9934 - val_loss: 0.2230 - val_accuracy: 0.9543
# Epoch 66/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0423 - accuracy: 0.9967 - val_loss: 0.2278 - val_accuracy: 0.9534
# Epoch 67/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0445 - accuracy: 0.9954 - val_loss: 0.2669 - val_accuracy: 0.9488
# Epoch 68/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0477 - accuracy: 0.9954 - val_loss: 0.2454 - val_accuracy: 0.9547
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 0.0006561000715009868.
# Epoch 69/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0413 - accuracy: 0.9972 - val_loss: 0.2322 - val_accuracy: 0.9573
# Epoch 70/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0430 - accuracy: 0.9962 - val_loss: 0.2063 - val_accuracy: 0.9585
# Epoch 71/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0332 - accuracy: 0.9981 - val_loss: 0.2078 - val_accuracy: 0.9534
# Epoch 72/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0258 - accuracy: 0.9996 - val_loss: 0.2245 - val_accuracy: 0.9556
# Epoch 73/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0219 - accuracy: 0.9993 - val_loss: 0.2170 - val_accuracy: 0.9581
# Epoch 74/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0234 - accuracy: 0.9985 - val_loss: 0.2232 - val_accuracy: 0.9543
# Epoch 75/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0454 - accuracy: 0.9932 - val_loss: 0.2789 - val_accuracy: 0.9467
# Epoch 76/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0463 - accuracy: 0.9955 - val_loss: 0.2673 - val_accuracy: 0.9543
# Epoch 77/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0415 - accuracy: 0.9964 - val_loss: 0.2669 - val_accuracy: 0.9492
# Epoch 78/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0395 - accuracy: 0.9963 - val_loss: 0.2612 - val_accuracy: 0.9475
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 0.0005904900433961303.
# Epoch 79/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0355 - accuracy: 0.9974 - val_loss: 0.2208 - val_accuracy: 0.9573
# Epoch 80/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0302 - accuracy: 0.9985 - val_loss: 0.2447 - val_accuracy: 0.9568
# Epoch 81/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0314 - accuracy: 0.9977 - val_loss: 0.2425 - val_accuracy: 0.9526
# Epoch 82/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0300 - accuracy: 0.9982 - val_loss: 0.2060 - val_accuracy: 0.9611
# Epoch 83/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0224 - accuracy: 0.9998 - val_loss: 0.1943 - val_accuracy: 0.9615
# Epoch 84/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0207 - accuracy: 0.9994 - val_loss: 0.2125 - val_accuracy: 0.9590
# Epoch 85/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0231 - accuracy: 0.9984 - val_loss: 0.2002 - val_accuracy: 0.9568
# Epoch 86/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0537 - accuracy: 0.9909 - val_loss: 0.2610 - val_accuracy: 0.9543
# Epoch 87/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0442 - accuracy: 0.9955 - val_loss: 0.2657 - val_accuracy: 0.9509
# Epoch 88/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0337 - accuracy: 0.9985 - val_loss: 0.2366 - val_accuracy: 0.9585
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 0.0005314410547725857.
# Epoch 89/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0275 - accuracy: 0.9991 - val_loss: 0.2358 - val_accuracy: 0.9556
# Epoch 90/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0232 - accuracy: 0.9995 - val_loss: 0.2302 - val_accuracy: 0.9534
# Epoch 91/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0199 - accuracy: 0.9995 - val_loss: 0.2257 - val_accuracy: 0.9568
# Epoch 92/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0217 - accuracy: 0.9985 - val_loss: 0.2341 - val_accuracy: 0.9590
# Epoch 93/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0226 - accuracy: 0.9983 - val_loss: 0.2235 - val_accuracy: 0.9581
# Epoch 94/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0243 - accuracy: 0.9984 - val_loss: 0.2336 - val_accuracy: 0.9543
# Epoch 95/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0371 - accuracy: 0.9949 - val_loss: 0.2502 - val_accuracy: 0.9496
# Epoch 96/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0369 - accuracy: 0.9960 - val_loss: 0.2454 - val_accuracy: 0.9539
# Epoch 97/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0309 - accuracy: 0.9981 - val_loss: 0.2496 - val_accuracy: 0.9539
# Epoch 98/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0261 - accuracy: 0.9986 - val_loss: 0.2411 - val_accuracy: 0.9577
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 0.00047829695977270604.
# Epoch 99/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0219 - accuracy: 0.9993 - val_loss: 0.2260 - val_accuracy: 0.9568
# Epoch 100/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0210 - accuracy: 0.9990 - val_loss: 0.2189 - val_accuracy: 0.9581
# Epoch 101/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0181 - accuracy: 0.9996 - val_loss: 0.2176 - val_accuracy: 0.9560
# Epoch 102/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0233 - accuracy: 0.9979 - val_loss: 0.2373 - val_accuracy: 0.9573
# Epoch 103/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0210 - accuracy: 0.9991 - val_loss: 0.2236 - val_accuracy: 0.9577
# Epoch 104/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0180 - accuracy: 0.9993 - val_loss: 0.2126 - val_accuracy: 0.9585
# Epoch 105/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0190 - accuracy: 0.9986 - val_loss: 0.2398 - val_accuracy: 0.9568
# Epoch 106/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0252 - accuracy: 0.9972 - val_loss: 0.2205 - val_accuracy: 0.9560
# Epoch 107/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0270 - accuracy: 0.9973 - val_loss: 0.2663 - val_accuracy: 0.9551
# Epoch 108/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0289 - accuracy: 0.9971 - val_loss: 0.2796 - val_accuracy: 0.9501
#
# Epoch 00108: ReduceLROnPlateau reducing learning rate to 0.0004304672533180565.
# Epoch 109/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0256 - accuracy: 0.9981 - val_loss: 0.2475 - val_accuracy: 0.9573
# Epoch 110/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0221 - accuracy: 0.9988 - val_loss: 0.2179 - val_accuracy: 0.9598
# Epoch 111/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0174 - accuracy: 0.9998 - val_loss: 0.2104 - val_accuracy: 0.9611
# Epoch 112/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0147 - accuracy: 0.9998 - val_loss: 0.2031 - val_accuracy: 0.9632
# Epoch 113/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0126 - accuracy: 0.9999 - val_loss: 0.2015 - val_accuracy: 0.9581
# Epoch 114/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9585
# Epoch 115/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0342 - accuracy: 0.9940 - val_loss: 0.2152 - val_accuracy: 0.9619
# Epoch 116/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0243 - accuracy: 0.9981 - val_loss: 0.2230 - val_accuracy: 0.9590
# Epoch 117/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0203 - accuracy: 0.9990 - val_loss: 0.2153 - val_accuracy: 0.9560
# Epoch 118/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0161 - accuracy: 0.9998 - val_loss: 0.2174 - val_accuracy: 0.9581
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 0.00038742052274756136.
# Epoch 119/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9602
# Epoch 120/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0116 - accuracy: 0.9999 - val_loss: 0.1905 - val_accuracy: 0.9611
# Epoch 121/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.1951 - val_accuracy: 0.9585
# Epoch 122/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0108 - accuracy: 0.9995 - val_loss: 0.2091 - val_accuracy: 0.9551
# Epoch 123/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0165 - accuracy: 0.9986 - val_loss: 0.2306 - val_accuracy: 0.9530
# Epoch 124/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0262 - accuracy: 0.9962 - val_loss: 0.2429 - val_accuracy: 0.9534
# Epoch 125/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0248 - accuracy: 0.9973 - val_loss: 0.2381 - val_accuracy: 0.9539
# Epoch 126/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0216 - accuracy: 0.9981 - val_loss: 0.2237 - val_accuracy: 0.9573
# Epoch 127/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0166 - accuracy: 0.9998 - val_loss: 0.2181 - val_accuracy: 0.9623
# Epoch 128/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0181 - accuracy: 0.9989 - val_loss: 0.2311 - val_accuracy: 0.9615
#
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 0.0003486784757114947.
# Epoch 129/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0154 - accuracy: 0.9997 - val_loss: 0.2205 - val_accuracy: 0.9611
# Epoch 130/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0136 - accuracy: 0.9997 - val_loss: 0.2044 - val_accuracy: 0.9632
# Epoch 131/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0119 - accuracy: 0.9997 - val_loss: 0.2173 - val_accuracy: 0.9560
# Epoch 132/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0102 - accuracy: 0.9999 - val_loss: 0.1968 - val_accuracy: 0.9615
# Epoch 133/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2075 - val_accuracy: 0.9564
# Epoch 134/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.1791 - val_accuracy: 0.9615
# Epoch 135/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0080 - accuracy: 0.9999 - val_loss: 0.2005 - val_accuracy: 0.9594
# Epoch 136/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0087 - accuracy: 0.9997 - val_loss: 0.2245 - val_accuracy: 0.9547
# Epoch 137/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0214 - accuracy: 0.9972 - val_loss: 0.2746 - val_accuracy: 0.9467
# Epoch 138/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0238 - accuracy: 0.9975 - val_loss: 0.2393 - val_accuracy: 0.9530
# Epoch 139/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0185 - accuracy: 0.9988 - val_loss: 0.2606 - val_accuracy: 0.9518
# Epoch 140/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0161 - accuracy: 0.9993 - val_loss: 0.2377 - val_accuracy: 0.9513
# Epoch 141/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0129 - accuracy: 0.9998 - val_loss: 0.2354 - val_accuracy: 0.9522
# Epoch 142/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0109 - accuracy: 0.9999 - val_loss: 0.2233 - val_accuracy: 0.9547
# Epoch 143/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0126 - accuracy: 0.9993 - val_loss: 0.2051 - val_accuracy: 0.9594
# Epoch 144/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0116 - accuracy: 0.9996 - val_loss: 0.2127 - val_accuracy: 0.9568
#
# Epoch 00144: ReduceLROnPlateau reducing learning rate to 0.00031381062290165574.
# Epoch 145/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0097 - accuracy: 0.9999 - val_loss: 0.2062 - val_accuracy: 0.9577
# Epoch 146/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0091 - accuracy: 0.9997 - val_loss: 0.2230 - val_accuracy: 0.9551
# Epoch 147/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0082 - accuracy: 0.9999 - val_loss: 0.1922 - val_accuracy: 0.9632
# Epoch 148/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0079 - accuracy: 0.9997 - val_loss: 0.2056 - val_accuracy: 0.9594
# Epoch 149/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0098 - accuracy: 0.9994 - val_loss: 0.2235 - val_accuracy: 0.9560
# Epoch 150/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0215 - accuracy: 0.9967 - val_loss: 0.2735 - val_accuracy: 0.9509
# Epoch 151/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0182 - accuracy: 0.9986 - val_loss: 0.2319 - val_accuracy: 0.9581
# Epoch 152/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9602
# Epoch 153/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0126 - accuracy: 0.9992 - val_loss: 0.2481 - val_accuracy: 0.9509
# Epoch 154/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0118 - accuracy: 0.9994 - val_loss: 0.2331 - val_accuracy: 0.9581
#
# Epoch 00154: ReduceLROnPlateau reducing learning rate to 0.0002824295632308349.
# Epoch 155/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0103 - accuracy: 0.9998 - val_loss: 0.2107 - val_accuracy: 0.9594
# Epoch 156/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9581
# Epoch 157/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.1940 - val_accuracy: 0.9594
# Epoch 158/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0074 - accuracy: 0.9998 - val_loss: 0.1905 - val_accuracy: 0.9590
# Epoch 159/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0116 - accuracy: 0.9991 - val_loss: 0.2275 - val_accuracy: 0.9534
# Epoch 160/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0119 - accuracy: 0.9992 - val_loss: 0.2091 - val_accuracy: 0.9594
# Epoch 161/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0115 - accuracy: 0.9992 - val_loss: 0.2199 - val_accuracy: 0.9577
# Epoch 162/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0110 - accuracy: 0.9992 - val_loss: 0.2135 - val_accuracy: 0.9547
# Epoch 163/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0115 - accuracy: 0.9992 - val_loss: 0.2433 - val_accuracy: 0.9509
# Epoch 164/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0107 - accuracy: 0.9994 - val_loss: 0.2136 - val_accuracy: 0.9581
#
# Epoch 00164: ReduceLROnPlateau reducing learning rate to 0.00025418660952709616.
# Epoch 165/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9573
# Epoch 166/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.2035 - val_accuracy: 0.9573
# Epoch 167/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.1965 - val_accuracy: 0.9594
# Epoch 168/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1860 - val_accuracy: 0.9581
# Epoch 169/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1841 - val_accuracy: 0.9590
# Epoch 170/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0076 - accuracy: 0.9993 - val_loss: 0.2662 - val_accuracy: 0.9484
# Epoch 171/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0201 - accuracy: 0.9964 - val_loss: 0.2260 - val_accuracy: 0.9539
# Epoch 172/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0128 - accuracy: 0.9993 - val_loss: 0.2203 - val_accuracy: 0.9534
# Epoch 173/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0108 - accuracy: 0.9995 - val_loss: 0.1984 - val_accuracy: 0.9560
# Epoch 174/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0102 - accuracy: 0.9996 - val_loss: 0.2198 - val_accuracy: 0.9518
#
# Epoch 00174: ReduceLROnPlateau reducing learning rate to 0.00022876793809700757.
# Epoch 175/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0089 - accuracy: 0.9998 - val_loss: 0.2014 - val_accuracy: 0.9547
# Epoch 176/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.1958 - val_accuracy: 0.9560
# Epoch 177/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9585
# Epoch 178/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1804 - val_accuracy: 0.9581
# Epoch 179/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.1769 - val_accuracy: 0.9577
# Epoch 180/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0061 - accuracy: 0.9997 - val_loss: 0.1886 - val_accuracy: 0.9590
# Epoch 181/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0064 - accuracy: 0.9998 - val_loss: 0.1977 - val_accuracy: 0.9543
# Epoch 182/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0065 - accuracy: 0.9998 - val_loss: 0.1933 - val_accuracy: 0.9611
# Epoch 183/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1936 - val_accuracy: 0.9602
# Epoch 184/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0070 - accuracy: 0.9996 - val_loss: 0.2092 - val_accuracy: 0.9577
# Epoch 185/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0067 - accuracy: 0.9999 - val_loss: 0.1923 - val_accuracy: 0.9619
# Epoch 186/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0066 - accuracy: 0.9998 - val_loss: 0.2008 - val_accuracy: 0.9602
# Epoch 187/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.1971 - val_accuracy: 0.9598
# Epoch 188/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0079 - accuracy: 0.9992 - val_loss: 0.1946 - val_accuracy: 0.9564
# Epoch 189/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0083 - accuracy: 0.9995 - val_loss: 0.2338 - val_accuracy: 0.9530
#
# Epoch 00189: ReduceLROnPlateau reducing learning rate to 0.00020589114428730683.
# Epoch 190/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0082 - accuracy: 0.9996 - val_loss: 0.2094 - val_accuracy: 0.9585
# Epoch 191/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0117 - accuracy: 0.9985 - val_loss: 0.2069 - val_accuracy: 0.9602
# Epoch 192/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0086 - accuracy: 0.9998 - val_loss: 0.2400 - val_accuracy: 0.9560
# Epoch 193/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0111 - accuracy: 0.9989 - val_loss: 0.2336 - val_accuracy: 0.9551
# Epoch 194/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0082 - accuracy: 0.9998 - val_loss: 0.2248 - val_accuracy: 0.9556
# Epoch 195/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2258 - val_accuracy: 0.9560
# Epoch 196/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2207 - val_accuracy: 0.9568
# Epoch 197/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0062 - accuracy: 0.9999 - val_loss: 0.2205 - val_accuracy: 0.9598
# Epoch 198/200
# 334/334 [==============================] - 4s 11ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.9590
# Epoch 199/200
# 334/334 [==============================] - 4s 12ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1972 - val_accuracy: 0.9590
#
# Epoch 00199: ReduceLROnPlateau reducing learning rate to 0.00018530203378759326.
# Epoch 00199: early stopping

# %%
model_json = model.to_json()
output = model.predict(test_X)
predicted_classes = output.argmax(axis=1)
answer_classes = test_Y.argmax(axis=1)
acc = accuracy_score(answer_classes, predicted_classes)
with open(save_path+"/model_acc_{:.4f}.json".format(acc), 'w') as json_file:
    json_file.write(model_json)

#Weight save
model.save_weights(save_path +"/final_weight.h5")
model_json = model.to_json()
with open(save_path+"/model.json".format(acc), 'w') as json_file:
    json_file.write(model_json)

# %%
from numpy.linalg import norm
def cos_sim(A,B):
    return np.dot(A, B)/(norm(A)*norm(B))

# %%
# def distance(vector1,vector2):
#     vector1 = np.array(vector1)
#     vector2 = np.array(vector2)
#     vector1 = vector1 - vector2
#     vector1 = vector1**2
#     return np.sqrt(vector1.sum())

def distance(vector1, vector2):
    return -10*cos_sim(vector1,vector2)

def openmax_param(model,trainx,trainy):
    import pandas as pd
    import keras
    from tensorflow.keras import optimizers
    class_num = len(np.array(model.weights[-1])) # Number of Class
    if len(np.shape(trainx))!=4:
        trainx = np.expand_dims(trainx,axis=-1)
    if len(trainy[0])==1:
        from keras.utils import to_categorical
        trainy = to_categorical(trainy,class_num)
    x_predict = model.predict(trainx)
    corr_ind = np.where(np.argmax(trainy,axis=-1)==np.argmax(x_predict,axis=-1))
    ver_X_train = trainx[corr_ind]
    ver_Y_train = trainy[corr_ind] # Step1 Data classified correctly
    new_model = keras.models.Sequential(model.layers[:-1])
    new_model.compile(optimizer='adam',loss='categorical_crossentropy',
                        metrics=['accuracy'])
    logit_vector = np.array(new_model.predict(ver_X_train))
    logit_matrix = [[]]*class_num
    for i in range(len(ver_X_train)): # Save Logit Vector by its class
        idx = np.argmax(ver_Y_train[i])
        logit_matrix[idx] = logit_matrix[idx]+[logit_vector[i]]
    mean_vector = []
    for i in range(len(logit_matrix)): # Compute Mean Vector
        mean_vector.append(np.array(logit_matrix[i]).mean(axis=0))
    distance_matrix=[[]]*class_num
    for idx in range(len(logit_matrix)):
        for logit in logit_matrix[idx]: # Save the distance
            distance_ = distance(logit,mean_vector[idx])
            distance_matrix[idx] = distance_matrix[idx]+[distance_]
    for i in range(len(distance_matrix)): # Sort
        distance_matrix[i] = np.array(distance_matrix[i])
        distance_matrix[i] = np.sort(distance_matrix[i])
    hyparam=[[]]*class_num;w=[[]]*class_num
    from scipy.stats import weibull_min
    for i in range(len(distance_matrix)): # Generate Weibull Distribution
        temp = weibull_min.fit(distance_matrix[i][-30:])
        hyparam[i] = hyparam[i]+list(temp)
    return hyparam, new_model, class_num, mean_vector

def openmax(xdata,returnvalue):
    from scipy.stats import weibull_min
    hyparam = returnvalue[0]; new_model = returnvalue[1]
    class_num = returnvalue[2]; mean_vector = returnvalue[3]
    pred = new_model.predict(xdata)
    new_logits=[]
    for idx in range(len(pred)):
        new_logit=[];unknown=0
        for ind in range(class_num):
            logit=pred[idx]
            distance_=distance(logit,mean_vector[ind])
            weight=weibull_min.cdf(distance_,hyparam[ind][0],
                                   hyparam[ind][1],hyparam[ind][2])
            new_logit.append(logit[ind]*(1-weight))
            unknown+=pred[idx][ind]*weight
        new_logit.append(unknown)
        new_logits.append(new_logit)
    output = []
    for i in new_logits:
        output.append(np.argmax(i))
    return output

# %%
def load_model(jsonpath,weightpath):
    with open(jsonpath) as f:
        json = f.read()
    model = tf.keras.models.model_from_json(json)
    model.load_weights(weightpath)
    return model

json='/content/gdrive/MyDrive/수학캡스톤_공유폴더/eunu/result/model.json'
weight='/content/gdrive/MyDrive/수학캡스톤_공유폴더/eunu/result/weights.179-0.1769-0.9577.hdf5'
model = load_model(json,weight)

# X_data = np.expand_dims(X_data,axis=-1)
# uknX = np.load('/content/gdrive/MyDrive/수학캡스톤_공유폴더/data/rawdata/X_30.npy')
# uknX = np.expand_dims(uknX,axis=-1)
# totalX = np.concatenate((X_data,uknX),axis=0)
# totalY = np.concatenate((Y_data,uknY),axis=0)

from sklearn.metrics import confusion_matrix, accuracy_score
temp = openmax_param(model,train_X,train_Y)
res = openmax(totalX,temp)
print(confusion_matrix(totalY, res))
print('Accuracy:',accuracy_score(totalY,res))
# Out:
# [[ 2341     0     0     0     0     0     0     0     0     0    36]
#  [    0  2339     0     0     0     0     0     0     0     0    36]
#  [    0     0  2335     0     0     1     1     0     0     0    38]
#  [    0     0     0  2327     0     0     0     1     0     2    29]
#  [    0     0     0     0  2326     0     0     0     0     0    27]
#  [    0     0     0     0     0  2347     1     0     0     1    18]
#  [    0     0     0     0     0     1  2337     1     0     0    28]
#  [    0     0     2     0     0     0     1  2314     0     0    40]
#  [    1     0     1     0     0     0     0     1  2348     0    29]
#  [    0     4     0     1     0     0     0     0     0  2327    40]
#  [  487   882  1110  1286   649  3543  2337   581  1285  2071 26808]]
# Accuracy: 0.7748489671049582

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
# uknX = np.load('/content/gdrive/MyDrive/수학캡스톤_공유폴더/data/rawdata/X_30.npy')
# uknX = np.expand_dims(uknX,axis=-1)
# uknY = np.load('/content/gdrive/MyDrive/수학캡스톤_공유폴더/data/rawdata/Y_30.npy')
temp = openmax_param(model,train_X,train_Y)
res = openmax(uknX,temp)
print(confusion_matrix(uknY, res))
print('Accuracy:',accuracy_score(uknY,res))

# %%
# temp = openmax_param(model,train_X,train_Y)
res = openmax(X_data,temp)
from sklearn.metrics import confusion_matrix, accuracy_score
print(confusion_matrix(Y_data, res))
print('Accuracy:',accuracy_score(Y_data,res))
# print(confusion_matrix(np.argmax(Y_data,axis=1), res))
# print('Accuracy:',accuracy_score(np.argmax(Y_data,axis=1),res))
